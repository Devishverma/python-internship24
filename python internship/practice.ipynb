# %%
import numpy
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os
# %matplotlib inline

# %%
auto =pd.read_csv("titanic.csv")
auto.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
plt.bar(auto["survived"],auto["sex"])
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
agevssex=auto.groupby(["age","sex"]).size().unstack(fill_value=0)
agevssex
# Out:
# sex    female  male
# age
# 0.42        0     1
# 0.67        0     1
# 0.75        2     0
# 0.83        0     2
# 0.92        0     1
# ...       ...   ...
# 70.00       0     2
# 70.50       0     1
# 71.00       0     2
# 74.00       0     1
# 80.00       0     1
#
# [88 rows x 2 columns]

# %%
survivedvssex.plot(kind='bar',stacked=True)
plt.show()

# %%
plt.figure(figsize=(30,10))

sns.lineplot(data=auto["who"],linewidth=1,label="who")
sns.lineplot(data=auto["survived"],linewidth=1,label="survived")

plt.title("who vs survived")
plt.xlabel("who")
plt.xlabel("survived")

plt.show()

# %%
plt.figure(figsize=(27,10))
sns.set(rc={"axes.facecolor":"#FFFFFF","axes.grid":False,"xtick.labelsize":10,"ytick.labelsize":10})

plt.title("sex VS survived")
plt.ylabel("sex")
plt.xlabel("survived")

sns.lineplot(x=auto["survived"],y=auto["sex"].index.values,color='g')

plt.show()

# %%
alonevssurvivedVSsex=auto.groupby(["alone","survived","sex"]).size().unstack(fill_value=0)
alonevssurvivedVSsex
# Out:
# sex             female  male
# alone survived
# False 0             54   121
#       1            134    45
# True  0             27   347
#       1             99    64

# %%
alonevssurvivedVSsex.plot(kind='bar',stacked=True)
plt.show()

# %%
data - pd.read_csv('titanic.csv') 
plt.figure(figsize=(8, 6))
sns.histplot(data["age"].dropna(), bins=30, kde=True, color='red') 
plt.title('Distribution of Passenger Ages') 
plt.xlabel('Age") 
plt.ylabel("Frequency')
plt.show()
# Out:
#   Cell In[100], line 5
#     plt.xlabel('Age")
#                ^
# SyntaxError: unterminated string literal (detected at line 5)
