# %%
import numpy as np

# %%
ar2=np.array([[85,90,78],[92,88,95],[76,95,85],[90,85,92],[88,76,89]])

# %%
ar2
# Out:
# array([[85, 90, 78],
#        [92, 88, 95],
#        [76, 95, 85],
#        [90, 85, 92],
#        [88, 76, 89]])

# %%
np.mean(ar2,axis=1)
# Out:
# array([84.33333333, 91.66666667, 85.33333333, 89.        , 84.33333333])

# %%
np.median(ar2,axis=0)
# Out:
# array([88., 88., 89.])

# %%
np.argmax(ar2)
# Out:
# 5

# %%
np.max(ar2,axis=0)
# Out:
# array([92, 95, 95])

# %%
np.min(ar2,axis=0)
# Out:
# array([76, 76, 78])

# %%
np.reshape(ar2,(3,5))
# Out:
# array([[85, 90, 78, 92, 88],
#        [95, 76, 95, 85, 90],
#        [85, 92, 88, 76, 89]])

# %%
np.sort(ar2,axis=1)
# Out:
# array([[78, 85, 90],
#        [88, 92, 95],
#        [76, 85, 95],
#        [85, 90, 92],
#        [76, 88, 89]])

# %%
np.argsort(ar2,axis=0)
# Out:
# array([[2, 4, 0],
#        [0, 3, 2],
#        [4, 1, 4],
#        [3, 0, 3],
#        [1, 2, 1]], dtype=int64)

# %%
sum=np.sum(ar2,axis=0)
print(max(sum))
# Out:
# 439

# %%
l=[1,2,3,4]
l[3]
# Out:
# 4

# %%
print("hello world")
# Out:
# hello world

# %%
print("hello world")
L

L(7)
L(3)

print("end of code")
# Out:
# hello world
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[62], line 2
#       1 print("hello world")
# ----> 2 L
#       4 L(7)
#       5 L(3)
#
# NameError: name 'L' is not defined

# %%
print("hello world")
L

print(L[3])
try:
    print([L7])
    except:
    print("invalid index")

print("end of code")
# Out:
#   Cell In[64], line 7
#     except:
#     ^
# SyntaxError: invalid syntax

# %%
a=30
b=4

try:
    print(a/b)
except:
    print("b cannot be zero!")
finally:
    print("end of code")
# Out:
# 7.5
# end of code

# %%
import numpy as np
import pandas as pd

# %%
dic={
    "name":["Ram","Shyam","Rayan","kajal","sameer"],
    "roll no":[1,2,3,4,5],
"grades":["A","B","A","c","B"],
"email":["abc@xyz.com","def@xyz.com","ghi@xyz.com","jkl@xyz.com","mno@xyz.com"]
}

# %%
dic
# Out:
# {'name': ['Ram', 'Shyam', 'Rayan', 'kajal', 'sameer'],
#  'roll no': [1, 2, 3, 4, 5],
#  'grades': ['A', 'B', 'A', 'c', 'B'],
#  'email': ['abc@xyz.com',
#   'def@xyz.com',
#   'ghi@xyz.com',
#   'jkl@xyz.com',
#   'mno@xyz.com']}

# %%
df=pd.DataFrame(dic)

# %%
df
# Out:
#      name  roll no grades        email
# 0     Ram        1      A  abc@xyz.com
# 1   Shyam        2      B  def@xyz.com
# 2   Rayan        3      A  ghi@xyz.com
# 3   kajal        4      c  jkl@xyz.com
# 4  sameer        5      B  mno@xyz.com

# %%
df.head()
# Out:
#      name  roll no grades        email
# 0     Ram        1      A  abc@xyz.com
# 1   Shyam        2      B  def@xyz.com
# 2   Rayan        3      A  ghi@xyz.com
# 3   kajal        4      c  jkl@xyz.com
# 4  sameer        5      B  mno@xyz.com

# %%
df.tail()
# Out:
#      name  roll no grades        email
# 0     Ram        1      A  abc@xyz.com
# 1   Shyam        2      B  def@xyz.com
# 2   Rayan        3      A  ghi@xyz.com
# 3   kajal        4      c  jkl@xyz.com
# 4  sameer        5      B  mno@xyz.com

# %%
df.head(2)
# Out:
#     name  roll no grades        email
# 0    Ram        1      A  abc@xyz.com
# 1  Shyam        2      B  def@xyz.com

# %%
df.tail(2)
# Out:
#      name  roll no grades        email
# 3   kajal        4      c  jkl@xyz.com
# 4  sameer        5      B  mno@xyz.com

# %%
df.describe()
# Out:
#         roll no
# count  5.000000
# mean   3.000000
# std    1.581139
# min    1.000000
# 25%    2.000000
# 50%    3.000000
# 75%    4.000000
# max    5.000000

# %%
df=pd.Series(dic)

# %%
df
# Out:
# name                      [Ram, Shyam, Rayan, kajal, sameer]
# roll no                                      [1, 2, 3, 4, 5]
# grades                                       [A, B, A, c, B]
# email      [abc@xyz.com, def@xyz.com, ghi@xyz.com, jkl@xy...
# dtype: object

# %%
df.

# %%
cus=pd.read_csv("py table.csv")

# %%
cus
# Out:
#     CustomerID                        Company Name       Costumer Name  \
# 0            1                 Alfreds Futterkiste        Maria Anders
# 1            2  Ana Trujillo Emparedados y helados        Ana Trujillo
# 2            3             Antonio Moreno Taqueria      Antonio Moreno
# 3            4                     Around the Horn        Thomas Hardy
# 4            5                   Berglunds snabbkp  Christina Berglund
# ..         ...                                 ...                 ...
# 86          87                      Wartian Herkku    Pirkko Koskitalo
# 87          88              Wellington Importadora       Paula Parente
# 88          89                White Clover Markets      Karl Jablonski
# 89          90                         Wilman Kala     Matti Karttunen
# 90          91                              Wolski             Zbyszek
#
#            City  PostalCode  Country
# 0        Berlin       12209  Germany
# 1   Mexico D.F.        5021   Mexico
# ...

# %%
    type(cus)
# Out:
# pandas.core.frame.DataFrame

# %%
cus.index
# Out:
# RangeIndex(start=0, stop=91, step=1)

# %%
cus.columns
# Out:
# Index(['CustomerID', 'Company Name', 'Costumer Name', 'City', 'PostalCode',
#        'Country'],
#       dtype='object')

# %%
cus.to_numpy()
# Out:
# array([[1, 'Alfreds Futterkiste', 'Maria Anders', 'Berlin', 12209,
#         'Germany'],
#        [2, 'Ana Trujillo Emparedados y helados', 'Ana Trujillo',
#         'Mexico D.F.', 5021, 'Mexico'],
#        [3, 'Antonio Moreno Taqueria', 'Antonio Moreno', 'Mexico D.F.',
#         5023, 'Mexico'],
#        [4, 'Around the Horn', 'Thomas Hardy', 'London', 34626, 'UK'],
#        [5, 'Berglunds snabbkp', 'Christina Berglund', 'Lulea', 95822,
#         'Sweden'],
#        [6, 'Blauer See Delikatessen', 'Hanna Moos', 'Mannheim', 68306,
#         'Germany'],
#        [7, 'Blondel pere et fils', 'Frederique Citeaux', 'Strasbourg',
#         67000, 'France'],
#        [8, 'BOlido Comidas preparadas', 'Martin Sommer', 'Madrid', 28023,
#         'Spain'],
#        [9, 'Bon app', 'Laurence Lebihans', 'Marseille', 13008, 'France'],
#        [10, 'Bottom-Dollar Marketse', 'Elizabeth Lincoln', 'Tsawassen',
#         254685, 'Canada'],
# ...

# %%
cus.T
# Out:
#                                 0                                   1   \
# CustomerID                       1                                   2
# Company Name   Alfreds Futterkiste  Ana Trujillo Emparedados y helados
# Costumer Name         Maria Anders                        Ana Trujillo
# City                        Berlin                         Mexico D.F.
# PostalCode                   12209                                5021
# Country                    Germany                              Mexico
#
#                                     2                3                   4   \
# CustomerID                           3                4                   5
# Company Name   Antonio Moreno Taqueria  Around the Horn   Berglunds snabbkp
# Costumer Name           Antonio Moreno     Thomas Hardy  Christina Berglund
# City                       Mexico D.F.           London               Lulea
# PostalCode                        5023            34626               95822
# ...

# %%
cus.drop(3)
# Out:
#     CustomerID                        Company Name       Costumer Name  \
# 0            1                 Alfreds Futterkiste        Maria Anders
# 1            2  Ana Trujillo Emparedados y helados        Ana Trujillo
# 2            3             Antonio Moreno Taqueria      Antonio Moreno
# 4            5                   Berglunds snabbkp  Christina Berglund
# 5            6             Blauer See Delikatessen          Hanna Moos
# ..         ...                                 ...                 ...
# 86          87                      Wartian Herkku    Pirkko Koskitalo
# 87          88              Wellington Importadora       Paula Parente
# 88          89                White Clover Markets      Karl Jablonski
# 89          90                         Wilman Kala     Matti Karttunen
# 90          91                              Wolski             Zbyszek
#
#            City  PostalCode  Country
# 0        Berlin       12209  Germany
# 1   Mexico D.F.        5021   Mexico
# ...

# %%
cus.loc[(48,78),("Company Name","Costumer Name")]
# Out:
#                     Company Name     Costumer Name
# 48  Magazzini Alimentari Riuniti  Giovanni Rovelli
# 78            Toms Spezialitaten     Karin Josephs

# %%
cus.loc[tuple(np.arange(48,78)),:]
# Out:
#     CustomerID                  Company Name        Costumer Name  \
# 48          49  Magazzini Alimentari Riuniti     Giovanni Rovelli
# 49          50                  Maison Dewey      Catherine Dewey
# 50          51                Mere Paillarde       Jean Fresniere
# 51          52        Morgenstern Gesundkost      Alexander Feuer
# 52          53                   North/South       Simon Crowther
# 53          54        Oceano Atlantico Ltda.       Yvonne Moncada
# 54          55        Old World Delicatessen        Rene Phillips
# 55          56            Ottilies Kaseladen  Henriette Pfalzheim
# 56          57             Paris specialites       Marie Bertrand
# 57          58     Pericles Comidas clasicas  Guillermo Fernandez
# 58          59              Piccolo und mehr          Georg Pipps
# 59          60       Princesa Isabel Vinhoss     Isabel de Castro
# 60          61                   Que Delicia     Bernardo Batista
# ...

# %%
cus.loc[:,"Company Name"]
# Out:
# 0                    Alfreds Futterkiste
# 1     Ana Trujillo Emparedados y helados
# 2                Antonio Moreno Taqueria
# 3                        Around the Horn
# 4                      Berglunds snabbkp
#                      ...
# 86                        Wartian Herkku
# 87                Wellington Importadora
# 88                  White Clover Markets
# 89                           Wilman Kala
# 90                                Wolski
# Name: Company Name, Length: 91, dtype: object

# %%
    companies = [
    {"employee_name": "John Doe", "company_name": "Tech Solutions", "position": "Software Engineer"},
    {"employee_name": "Jane Smith", "company_name": "Creative Minds", "position": "Graphic Designer"},
    {"employee_name": "Sam Johnson", "company_name": "Financial Experts", "position": "Financial Analyst"},
    {"employee_name": "Lisa Brown", "company_name": "Health First", "position": "Nurse"},
    {"employee_name": "Tom White", "company_name": "EduTech", "position": "Teacher"},
    {"employee_name": "Anna Green", "company_name": "Marketing Gurus", "position": "Marketing Manager"},
    {"employee_name": "Mark Black", "company_name": "AutoWorks", "position": "Mechanical Engineer"},
    {"employee_name": "Nancy Wilson", "company_name": "Retail World", "position": "Sales Associate"},
    {"employee_name": "Paul Adams", "company_name": "Foodies", "position": "Chef"},
    {"employee_name": "Susan Davis", "company_name": "Fashion Forward", "position": "Fashion Designer"},
    {"employee_name": "Robert Brown", "company_name": "Tech Solutions", "position": "Project Manager"},
    {"employee_name": "Emma White", "company_name": "Creative Minds", "position": "Content Writer"},
    {"employee_name": "James Green", "company_name": "Financial Experts", "position": "Accountant"},
    {"employee_name": "Patricia Black", "company_name": "Health First", "position": "Doctor"},
    {"employee_name": "Michael Wilson", "company_name": "EduTech", "position": "Principal"},
    {"employee_name": "Linda Adams", "company_name": "Marketing Gurus", "position": "SEO Specialist"},
    {"employee_name": "Christopher Davis", "company_name": "AutoWorks", "position": "Automotive Technician"},
    {"employee_name": "Karen Brown", "company_name": "Retail World", "position": "Store Manager"},
    {"employee_name": "Daniel White", "company_name": "Foodies", "position": "Sous Chef"},
    {"employee_name": "Barbara Green", "company_name": "Fashion Forward", "position": "Retail Buyer"},
    {"employee_name": "Charles Black", "company_name": "Tech Solutions", "position": "Systems Analyst"},
    {"employee_name": "Jessica Wilson", "company_name": "Creative Minds", "position": "Art Director"},
    {"employee_name": "George Adams", "company_name": "Financial Experts", "position": "Investment Banker"},
    {"employee_name": "Mary Davis", "company_name": "Health First", "position": "Pharmacist"},
    {"employee_name": "Steven Brown", "company_name": "EduTech", "position": "Math Teacher"},
    {"employee_name": "Susan White", "company_name": "Marketing Gurus", "position": "Social Media Manager"},
    {"employee_name": "Paul Green", "company_name": "AutoWorks", "position": "Service Advisor"},
    {"employee_name": "Linda Black", "company_name": "Retail World", "position": "Customer Service Representative"},
    {"employee_name": "David Wilson", "company_name": "Foodies", "position": "Pastry Chef"},
    {"employee_name": "Sarah Adams", "company_name": "Fashion Forward", "position": "Merchandise Planner"},
    {"employee_name": "James Davis", "company_name": "Tech Solutions", "position": "Database Administrator"},
    {"employee_name": "Lisa Brown", "company_name": "Creative Minds", "position": "Copywriter"},
    {"employee_name": "Michael White", "company_name": "Financial Experts", "position": "Financial Planner"},
    {"employee_name": "Karen Green", "company_name": "Health First", "position": "Physical Therapist"},
    {"employee_name": "John Black", "company_name": "EduTech", "position": "Science Teacher"},
    {"employee_name": "Patricia Wilson", "company_name": "Marketing Gurus", "position": "Brand Manager"},
    {"employee_name": "Christopher Adams", "company_name": "AutoWorks", "position": "Parts Specialist"},
    {"employee_name": "Nancy Davis", "company_name": "Retail World", "position": "Visual Merchandiser"},
    {"employee_name": "Steven Brown", "company_name": "Foodies", "position": "Line Cook"},
    {"employee_name": "Jessica White", "company_name": "Fashion Forward", "position": "Stylist"},
    {"employee_name": "George Green", "company_name": "Tech Solutions", "position": "IT Support Specialist"},
    {"employee_name": "Mary Black", "company_name": "Creative Minds", "position": "Illustrator"},
    {"employee_name": "James Wilson", "company_name": "Financial Experts", "position": "Auditor"},
    {"employee_name": "Susan Adams", "company_name": "Health First", "position": "Medical Assistant"},
    {"employee_name": "Paul Davis", "company_name": "EduTech", "position": "History Teacher"},
    {"employee_name": "Linda Brown", "company_name": "Marketing Gurus", "position": "Content Strategist"},
    {"employee_name": "David White", "company_name": "AutoWorks", "position": "Shop Foreman"},
    {"employee_name": "Sarah Green", "company_name": "Retail World", "position": "Cashier"},
    {"employee_name": "James Black", "company_name": "Foodies", "position": "Bartender"},
    {"employee_name": "Lisa Wilson", "company_name": "Fashion Forward", "position": "Product Developer"},
]
companies
# Out:
# [{'employee_name': 'John Doe',
#   'company_name': 'Tech Solutions',
#   'position': 'Software Engineer'},
#  {'employee_name': 'Jane Smith',
#   'company_name': 'Creative Minds',
#   'position': 'Graphic Designer'},
#  {'employee_name': 'Sam Johnson',
#   'company_name': 'Financial Experts',
#   'position': 'Financial Analyst'},
#  {'employee_name': 'Lisa Brown',
#   'company_name': 'Health First',
#   'position': 'Nurse'},
#  {'employee_name': 'Tom White',
#   'company_name': 'EduTech',
#   'position': 'Teacher'},
#  {'employee_name': 'Anna Green',
#   'company_name': 'Marketing Gurus',
#   'position': 'Marketing Manager'},
#  {'employee_name': 'Mark Black',
#   'company_name': 'AutoWorks',
#   'position': 'Mechanical Engineer'},
#  {'employee_name': 'Nancy Wilson',
#   'company_name': 'Retail World',
#   'position': 'Sales Associate'},
#  {'employee_name': 'Paul Adams',
#   'company_name': 'Foodies',
#   'position': 'Chef'},
#  {'employee_name': 'Susan Davis',
# ...

# %%
cd=pd.DataFrame(companies)

# %%
cd
# Out:
#         employee_name       company_name                         position
# 0            John Doe     Tech Solutions                Software Engineer
# 1          Jane Smith     Creative Minds                 Graphic Designer
# 2         Sam Johnson  Financial Experts                Financial Analyst
# 3          Lisa Brown       Health First                            Nurse
# 4           Tom White            EduTech                          Teacher
# 5          Anna Green    Marketing Gurus                Marketing Manager
# 6          Mark Black          AutoWorks              Mechanical Engineer
# 7        Nancy Wilson       Retail World                  Sales Associate
# 8          Paul Adams            Foodies                             Chef
# 9         Susan Davis    Fashion Forward                 Fashion Designer
# 10       Robert Brown     Tech Solutions                  Project Manager
# 11         Emma White     Creative Minds                   Content Writer
# ...

# %%
cd.drop_duplicates(subset="position",keep="last")
# Out:
#         employee_name       company_name                         position
# 0            John Doe     Tech Solutions                Software Engineer
# 1          Jane Smith     Creative Minds                 Graphic Designer
# 2         Sam Johnson  Financial Experts                Financial Analyst
# 3          Lisa Brown       Health First                            Nurse
# 4           Tom White            EduTech                          Teacher
# 5          Anna Green    Marketing Gurus                Marketing Manager
# 6          Mark Black          AutoWorks              Mechanical Engineer
# 7        Nancy Wilson       Retail World                  Sales Associate
# 8          Paul Adams            Foodies                             Chef
# 9         Susan Davis    Fashion Forward                 Fashion Designer
# 10       Robert Brown     Tech Solutions                  Project Manager
# 11         Emma White     Creative Minds                   Content Writer
# ...

# %%
import numpy as np
import pandas as pd 
from matplotlib import pyplot as plt

# %%
sm=pd.read_csv('student_marks.csv')
sm
# Out:
#      Roll No                     Name  English  Hindi  Maths  Science  SST
# 0          1            A HariCharan        80     66     98       21   41
# 1          2  A Mohammed Sahil Aiyan        72     73     81       56   83
# 2          3           A Pavan Kumar        41     46     26        7   35
# 3          4            Aaditya Nanda       64     99      6       16   72
# 4          5        Aakanksha Kaushal       38     20     40       33   50
# ..       ...                      ...      ...    ...    ...      ...  ...
# 554      555           Yamini Priya K       57     52     77       95   77
# 555      556         YARUKALA ALEKHYA       11     24     18       28    5
# 556      557           YOGESH KOTHARI        8     12     29       32   32
# 557      558       ZAKKAM ABHIGNA RAJ       85     72     97       90   79
# 558      559               Zoha Shaik       95     86     59       81   77
#
# [559 rows x 7 columns]

# %%
sm['Total']=sm[['English','Hindi','Maths','Science','SST']].sum(axis=1)

# %%
sm
# Out:
#      Roll No                     Name  English  Hindi  Maths  Science  SST  \
# 0          1            A HariCharan        80     66     98       21   41
# 1          2  A Mohammed Sahil Aiyan        72     73     81       56   83
# 2          3           A Pavan Kumar        41     46     26        7   35
# 3          4            Aaditya Nanda       64     99      6       16   72
# 4          5        Aakanksha Kaushal       38     20     40       33   50
# ..       ...                      ...      ...    ...    ...      ...  ...
# 554      555           Yamini Priya K       57     52     77       95   77
# 555      556         YARUKALA ALEKHYA       11     24     18       28    5
# 556      557           YOGESH KOTHARI        8     12     29       32   32
# 557      558       ZAKKAM ABHIGNA RAJ       85     72     97       90   79
# 558      559               Zoha Shaik       95     86     59       81   77
#
#      Total
# 0      306
# 1      365
# 2      155
# 3      257
# ...

# %%
sm['Percentage']=sm['Total']/5

# %%
sm
# Out:
#      Roll No                     Name  English  Hindi  Maths  Science  SST  \
# 0          1            A HariCharan        80     66     98       21   41
# 1          2  A Mohammed Sahil Aiyan        72     73     81       56   83
# 2          3           A Pavan Kumar        41     46     26        7   35
# 3          4            Aaditya Nanda       64     99      6       16   72
# 4          5        Aakanksha Kaushal       38     20     40       33   50
# ..       ...                      ...      ...    ...    ...      ...  ...
# 554      555           Yamini Priya K       57     52     77       95   77
# 555      556         YARUKALA ALEKHYA       11     24     18       28    5
# 556      557           YOGESH KOTHARI        8     12     29       32   32
# 557      558       ZAKKAM ABHIGNA RAJ       85     72     97       90   79
# 558      559               Zoha Shaik       95     86     59       81   77
#
#      Total  Percentage
# 0      306        61.2
# ...

# %%
Grade
A=100-80
B=80-60
C=60-50
D=50-40
E=40-30
F=0-30

# %%
def clac_grade(p):
    if p<=80 and p>=100:
        return 'A'
    elif p<80 and p>60:
        return 'B'
    elif p<60 and p>50:
        return 'C'
    elif p<50 and p>40:
        return 'D'
    elif p<40 and p>30:
        return 'E'
    elif p<0 and p>30:
        return 'F'
    else:
        return'X'
    sm['Grade']=sm['Percentage'].apply(clac_grade)

# %%
sm
# Out:
#      Roll No                     Name  English  Hindi  Maths  Science  SST  \
# 0          1            A HariCharan        80     66     98       21   41
# 1          2  A Mohammed Sahil Aiyan        72     73     81       56   83
# 2          3           A Pavan Kumar        41     46     26        7   35
# 3          4            Aaditya Nanda       64     99      6       16   72
# 4          5        Aakanksha Kaushal       38     20     40       33   50
# ..       ...                      ...      ...    ...    ...      ...  ...
# 554      555           Yamini Priya K       57     52     77       95   77
# 555      556         YARUKALA ALEKHYA       11     24     18       28    5
# 556      557           YOGESH KOTHARI        8     12     29       32   32
# 557      558       ZAKKAM ABHIGNA RAJ       85     72     97       90   79
# 558      559               Zoha Shaik       95     86     59       81   77
#
#      Total  Percentage
# 0      306        61.2
# ...

# %%
plt.figure(figsize=(10,6))
for sub in ['English','Hindi','Maths','Science','SST']:
    plt.plot(sm['Name'],sm[sub],marker='o',label=sub)
    plt.title("Marks in different Subjects")
    plt.xlabel('Name')
    plt.ylabel('Marks')
    plt.legend()
    plt.grid(True)
    plt.show()

# %%
temp=sm.head()
temp
# Out:
#    Roll No                     Name  English  Hindi  Maths  Science  SST  \
# 0        1            A HariCharan        80     66     98       21   41
# 1        2  A Mohammed Sahil Aiyan        72     73     81       56   83
# 2        3           A Pavan Kumar        41     46     26        7   35
# 3        4            Aaditya Nanda       64     99      6       16   72
# 4        5        Aakanksha Kaushal       38     20     40       33   50
#
#    Total  Percentage
# 0    306        61.2
# 1    365        73.0
# 2    155        31.0
# 3    257        51.4
# 4    181        36.2

# %%
plt.figure(figsize=(10,6))
for sub in ['English','Hindi','Maths','Science','SST']:
    plt.plot(temp['Name'],temp[sub],marker='o',label=sub)
    plt.title("Marks in different Subjects")
    plt.xlabel('Name')
    plt.ylabel('Marks')
    plt.legend()
    plt.grid(True)
    plt.show()

# %%
 sub=['English','Hindi','Maths','Science','SST']
col=['b','g','r','y','m']
for i in range(5) :
    plt.figure(figsize=(10,6))
    plt.plot(temp['Name'],temp[sub],marker='o',color=col[i],label=sub)
    plt.title("Marks in different Subjects")
    plt.xlabel('Name')
    plt.ylabel('Marks')
    plt.legend()
    plt.grid(True)
    plt.show()

# %%
 sub=['English','Hindi','Maths','Science','SST']
 plt.figure(figsize=(10,6))
 plt.plot(temp['Name'],temp[sub],marker='o',label=sub)
 plt.title("Marks in different Subjects")
 plt.xlabel('Name')
 plt.ylabel('Marks')
 plt.legend()
 plt.grid(True)
 plt.show()
